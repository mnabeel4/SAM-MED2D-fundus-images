# %%
using_colab = True

# %%
# !git clone https://github.com/uni-medical/SAM-Med2D.git SAM_Med2D
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'

    # !mkdir images
    # !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/dog.jpg

else:
    # not sure for this part! Please check!
    # !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
    # !pip install opencv-python matplotlib
    # !pip install 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
# 'git' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# PyTorch version: 1.11.0+cu113
# Torchvision version: 0.12.0+cu113
# CUDA is available: True
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (4.8.1.78)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (3.7.4)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\sam-med2d\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2
import sys

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
image = cv2.imread('H:/data/new-fundus-dataset/new-fundus-dataset/fundus-data-org/C0007239.jpg')
image.shape
# Out:
# (1696, 2544, 3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

# %%
print(sys.path)
# Out:
# ['H:\\workspace\\Nabeel\\SAM-Med2D', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\python38.zip', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\DLLs', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\lib', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D', '', 'C:\\Users\\Administrator\\AppData\\Roaming\\Python\\Python38\\site-packages', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\envs\\SAM-med2D\\lib\\site-packages\\Pythonwin']

# %%
from segment_anything import sam_model_registry
from segment_anything.predictor_sammed import SammedPredictor
from argparse import Namespace
args = Namespace()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
args.image_size = 256
args.encoder_adapter = True
args.sam_checkpoint = "pretrain_model/sam-med2d_b.pth"
model = sam_model_registry["vit_b"](args).to(device)
predictor = SammedPredictor(model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 from segment_anything import sam_model_registry
# ----> 2 from segment_anything.predictor_sammed import SammedPredictor
#       3 from argparse import Namespace
#       4 args = Namespace()
#
# File H:\workspace\Nabeel\SAM-Med2D\segment_anything\predictor_sammed.py:6
#       4 from torch.nn import functional as F
#       5 from copy import deepcopy
# ----> 6 from albumentations.pytorch import ToTensorV2
#       7 import albumentations as A
#       8 import cv2
#
# ModuleNotFoundError: No module named 'albumentations'
